# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler,MinMaxScaler

# %%
df =pd.read_csv('/content/House_Pricing.csv')
df
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
df['Waterfront View'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Flat Area (in Sqft)'].unique()
# Out:
# array([1180., 2570.,  770., ..., 3087., 3118., 1425.])

# %%
df['Lot Area (in Sqft)'].unique()
# Out:
# array([ 5650.,  7242., 10000., ...,  5813.,  2388.,  1076.])

# %%
df['Basement Area (in Sqft)'].unique()
# Out:
# array([   0,  400,  910, 1530,  730, 1700,  300,  970,  760,  720,  700,
#         820,  780,  790,  330, 1620,  360,  588, 1510,  410,  990,  600,
#         560,  550, 1000, 1600,  500, 1040,  880, 1010,  240,  265,  290,
#         800,  540,  380,  710,  840,  770,  480,  570, 1490,  620, 1250,
#        1270,  120,  650,  180, 1130,  450, 1640, 1460, 1020, 1030,  750,
#         640, 1070,  490, 1310,  630, 2000,  390,  430,  850,  210, 1430,
#        1950,  440,  220, 1160,  860,  580, 2060, 1820, 1180,  200, 1150,
#        1200,  680,  530, 1450, 1170, 1080,  960, 1100,  280,  870,  460,
#        1400, 1320,  660, 1220,  900,  420, 1580, 1380,  475,  690,  270,
#         350,  935, 1370,  980, 1470,  160,  950,   50,  740, 1780, 1900,
#         340,  470,  370,  140, 1760,  130,  610,  520,  890, 1110,  150,
#        1720,  810,  190, 1290,  670, 1800, 1120, 1810,   60, 1050,  940,
#         310,  930, 1390, 1830, 1300,  510, 1330, 1590,  920, 1420, 1240,
# ...

# %%
df.drop(columns=['Waterfront View','Date House was Sold','No of Times Visited','Lot Area (in Sqft)'],inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['Flat Area (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Flat Area (in Sqft)', ylabel='Count'>

# %%
df['Flat Area (in Sqft)'].fillna(df['Flat Area (in Sqft)'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Sale Price'],kde=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
df['Sale Price'].fillna(df['Sale Price'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['No of Bathrooms'],kde=True)
# Out:
# <Axes: xlabel='No of Bathrooms', ylabel='Count'>

# %%
df['No of Bathrooms'].fillna(df['No of Bathrooms'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Area of the House from Basement (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Area of the House from Basement (in Sqft)', ylabel='Count'>

# %%
df['Area of the House from Basement (in Sqft)'].fillna(df['Area of the House from Basement (in Sqft)'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Zipcode'],kde=True)
# Out:
# <Axes: xlabel='Zipcode', ylabel='Count'>

# %%
df['Zipcode'].fillna(df['Zipcode'].mode()[0],inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Latitude'],kde=True)
# Out:
# <Axes: xlabel='Latitude', ylabel='Count'>

# %%
df['Latitude'].fillna(df['Latitude'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Longitude'],kde=True)
# Out:
# <Axes: xlabel='Longitude', ylabel='Count'>

# %%
df['Longitude'].fillna(df['Longitude'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(df['Living Area after Renovation (in Sqft)'],kde=True)
# Out:
# <Axes: xlabel='Living Area after Renovation (in Sqft)', ylabel='Count'>

# %%
df['Living Area after Renovation (in Sqft)'].fillna(df['Living Area after Renovation (in Sqft)'].median(),inplace=True)
df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# No of Floors                                 0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 17 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   No of Floors                               21613 non-null  float64
#  6   Condition of the House                     21613 non-null  object
#  7   Overall Grade                              21613 non-null  int64
#  8   Area of the House from Basement (in Sqft)  21613 non-null  float64
#  9   Basement Area (in Sqft)                    21613 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Sale Price', 'No of Bedrooms', 'No of Bathrooms',
#        'Flat Area (in Sqft)', 'No of Floors', 'Condition of the House',
#        'Overall Grade', 'Area of the House from Basement (in Sqft)',
#        'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
#        'Zipcode', 'Latitude', 'Longitude',
#        'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
Categorical_col=['Condition of the House']
numerical_col=['Flat Area (in Sqft)','Basement Area (in Sqft)','Area of the House from Basement (in Sqft)','Zipcode','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
data_encoded = pd.get_dummies(df,columns=Categorical_col,dtype=int,drop_first=True)
data_encoded
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Sale Price                                 21613 non-null  float64
#  2   No of Bedrooms                             21613 non-null  int64
#  3   No of Bathrooms                            21613 non-null  float64
#  4   Flat Area (in Sqft)                        21613 non-null  float64
#  5   No of Floors                               21613 non-null  float64
#  6   Overall Grade                              21613 non-null  int64
#  7   Area of the House from Basement (in Sqft)  21613 non-null  float64
#  8   Basement Area (in Sqft)                    21613 non-null  int64
#  9   Age of House (in Years)                    21613 non-null  int64
# ...

# %%
data_encoded.shape
# Out:
# (21613, 20)

# %%
data_std_scaled =data_encoded.copy()

std_scaler = StandardScaler()
data_std_scaled[numerical_col] = std_scaler.fit_transform(data_std_scaled[numerical_col])
data_std_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00            -0.979820              5650.0           1.0
# 1             2.25             0.533572              7242.0           2.0
# 2             1.00            -1.426216             10000.0           1.0
# 3             3.00            -0.130578              5000.0           1.0
# 4             2.00            -0.435434              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  Renovated Year   Zipcode  \
# 0              No                 NaN  ...               0  1.870176
# ...

# %%
data_std_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.160400e+04        2.160400e+04  21613.000000   21613.000000
# mean         -1.184019e-16        1.510776e+04      1.494309       7.623467
# std           1.000023e+00        4.142827e+04      0.539989       1.105439
# ...

# %%
data_minmax_scaled =data_encoded.copy()

minmax_scaler = MinMaxScaler()
data_minmax_scaled[numerical_col] = std_scaler.fit_transform(data_minmax_scaled[numerical_col])
data_minmax_scaled.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00            -0.979820              5650.0           1.0
# 1             2.25             0.533572              7242.0           2.0
# 2             1.00            -1.426216             10000.0           1.0
# 3             3.00            -0.130578              5000.0           1.0
# 4             2.00            -0.435434              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  Renovated Year   Zipcode  \
# 0              No                 NaN  ...               0  1.870176
# ...

# %%
data_minmax_scaled.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         2.160400e+04        2.160400e+04  21613.000000   21613.000000
# mean         -1.184019e-16        1.510776e+04      1.494309       7.623467
# std           1.000023e+00        4.142827e+04      0.539989       1.105439
# ...

# %%
corr_columns =['Flat Area (in Sqft)','Basement Area (in Sqft)','Area of the House from Basement (in Sqft)','Zipcode','Latitude','Longitude','Living Area after Renovation (in Sqft)']
original_data_corr =data_encoded[corr_columns].corr()
original_data_corr
# Out:
#                                            Flat Area (in Sqft)  \
# Flat Area (in Sqft)                                   1.000000
# Basement Area (in Sqft)                               0.435230
# Area of the House from Basement (in Sqft)             0.876587
# Zipcode                                              -0.199416
# Latitude                                              0.052543
# Longitude                                             0.240152
# Living Area after Renovation (in Sqft)                0.756357
#
#                                            Basement Area (in Sqft)  \
# Flat Area (in Sqft)                                       0.435230
# Basement Area (in Sqft)                                   1.000000
# Area of the House from Basement (in Sqft)                -0.051821
# Zipcode                                                   0.074854
# Latitude                                                  0.110554
# ...
